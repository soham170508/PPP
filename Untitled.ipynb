# %% [markdown]
# Soham Joshi

# %% [markdown]
# 1. Write a progarm to check Radio Frequencey and Audio Frequency

# %%
f = float(input("Enter frequency in Hz: "))

if f <= 20000:
    print("Audio frequency (AF)")
else:
    print("Radio frequency (RF)")
# Out:
# Enter frequency in Hz:  25000
# Radio frequency (RF)
