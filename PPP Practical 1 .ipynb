# %%
r1= float(input("r1"))
r2= float(input("r2"))
rs= r1+r2
print(rs)
# Out:
# r1 20
# r2 60
# 80.0

# %%
r1= float(input("r1"))
r2= float(input("r2"))
rp= 1/(1/r1)+(1/r2)
print(rp)
# Out:
# r1 4
# r2 2
# 4.5

# %%
i=20
r=30

v=i*r
print(v)
# Out:
# 600
