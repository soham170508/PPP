# %% [markdown]
# Soham Joshi    24204C0021  TE4KC

# %%
import math

Vm = float(input("Enter peak voltage Vm: "))
Vdc = Vm / math.pi

print("DC Output Voltage (Vdc):", Vdc)
# Out:
# Enter peak voltage Vm:  10
# DC Output Voltage (Vdc): 3.183098861837907

# %%
import statistics

data = [10, 20, 20, 30, 40]

print("Data:", data)
print("Mean:", statistics.mean(data))
print("Median:", statistics.median(data))
print("Mode:", statistics.mode(data))
print("Standard Deviation:", statistics.stdev(data))
# Out:
# Data: [10, 20, 20, 30, 40]
# Mean: 24
# Median: 20
# Mode: 20
# Standard Deviation: 11.40175425099138

# %%
# User-defined calculator module using class (single code)

class Calculator:
    def add(self, a, b):
        return a + b

    def subtract(self, a, b):
        return a - b

    def multiply(self, a, b):
        return a * b

    def divide(self, a, b):
        return a / b


# Using the user-defined module
calc = Calculator()

print("Addition:", calc.add(10, 5))
print("Subtraction:", calc.subtract(10, 5))
print("Multiplication:", calc.multiply(10, 5))
print("Division:", calc.divide(10, 5))
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0

# %% [markdown]
# Debugging Questions with Corrected Answers

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
import calculator
print(calculator.add(5, 3))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import calculator
#       2 print(calculator.add(5, 3))
#
# ModuleNotFoundError: No module named 'calculator'
