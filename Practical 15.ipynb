# %% [markdown]
# Soham Joshi 24204C021

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
class LinkedList:
    def __init__(self):
        self.head = None

    def create(self, data_list):
        for data in data_list:
            self.insert_end(data)

    def insert_end(self, data):S
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            temp = self.head
            while temp.next:
                temp = temp.next
            temp.next = new_node

    def traverse(self):
        temp = self.head
        while temp:
            print(temp.data, end=" -> ")
            temp = temp.next
        print("None")


ll = LinkedList()
ll.create([10, 20, 30, 40])
ll.traverse()
# Out:
# 10 -> 20 -> 30 -> 40 -> None

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def insert_beginning(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node

    def traverse(self):
        temp = self.head
        while temp:
            print(temp.data, end=" -> ")
            temp = temp.next
        print("None")


# Testing
ll = LinkedList()
ll.insert_beginning(30)
ll.insert_beginning(20)
ll.insert_beginning(10)
ll.traverse()
# Out:
# 10 -> 20 -> 30 -> None

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def insert_end(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            return
        temp = self.head
        while temp.next:
            temp = temp.next
        temp.next = new_node

    def delete(self, key):
        temp = self.head

        # If head node holds the key
        if temp and temp.data == key:
            self.head = temp.next
            temp = None
            return

        prev = None
        while temp and temp.data != key:
            prev = temp
            temp = temp.next

        if temp is None:
            print("Element not found")
            return

        prev.next = temp.next
        temp = None

    def traverse(self):
        temp = self.head
        while temp:
            print(temp.data, end=" -> ")
            temp = temp.next
        print("None")
ll = LinkedList()
ll.insert_end(10)
ll.insert_end(20)
ll.insert_end(30)
ll.traverse()

ll.delete(20)
ll.traverse()
# Out:
# 10 -> 20 -> 30 -> None
# 10 -> 30 -> None

# %%
class Node:
    def __init__(00):
        self.data = data
# Out:
#   Cell In[6], line 2
#     def __init__(00):
#                  ^
# SyntaxError: invalid syntax

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# %%
if temp.data = key:
    head = temp.next
# Out:
#   Cell In[10], line 1
#     if temp.data = key:
#        ^
# SyntaxError: cannot assign to attribute here. Maybe you meant '==' instead of '='?

# %%
if temp.data == key:
    head = temp.next
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 if temp.data == key:
#       2     head = temp.next
#
# NameError: name 'temp' is not defined
